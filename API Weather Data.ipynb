# %%
import requests
import os
from datetime import datetime
import tkinter as tk

# %%
user_api = os.environ['weather_data']
location = input('Enter city name: ')

complete_api_link = "https://api.openweathermap.org/data/2.5/weather?q="+location+"&appid="+user_api
api_link = requests.get(complete_api_link)
api_data = api_link.json()

#create variables to store and display data
temp_city = ((api_data['main']['temp']) - 273.15)
weather_desc = api_data['weather'][0]['description']
hmdt = api_data['main']['humidity']
wind_spd = api_data['wind']['speed']
date_time = datetime.now().strftime("%d %b %Y | %I:%M:%S %p")

print ("-------------------------------------------------------------")
print ("Weather Stats for - {}  || {}".format(location.upper(), date_time))
print ("-------------------------------------------------------------")

print ("Current temperature is: {:.1f} deg C".format(temp_city))
print ("Current weather desc  :",weather_desc)
print ("Current Humidity      :",hmdt, '%')
print ("Current wind speed    :",wind_spd ,'kmph')
# Out:
# Enter city name: Bandung
# -------------------------------------------------------------
# Weather Stats for - BANDUNG  || 18 Jan 2022 | 03:58:30 PM
# -------------------------------------------------------------
# Current temperature is: 24.9 deg C
# Current weather desc  : overcast clouds
# Current Humidity      : 87 %
# Current wind speed    : 2.24 kmph

# %%
def getweather(canvas):
    city = textField.get()
    api = complete_api_link
    json_data = api_data
    
    condition = json_data['weather'][0]['main']
    temp = int(json_data['main']['temp'] - 273.15)
    min_temp = int(json_data['main']['temp_min'] - 273.15)
    max_temp = int(json_data['main']['temp_max'] - 273.15)
    pressure = json_data['main']['pressure']
    humidity = json_data['main']['humidity']
    wind = json_data['wind']['speed']
    
    
    
    final_info = condition + "\n" + str(temp) + "°C" 
    final_data = "\n"+ "Min Temp: " + str(min_temp) + "°C" + "\n" + "Max Temp: " + str(max_temp) + "°C" +"\n" + "Pressure: " + str(pressure) + "\n" +"Humidity: " + str(humidity) + "\n" +"Wind Speed: " + str(wind) + "\n"
    label1.config(text = final_info)
    label2.config(text = final_data)

# %%
canvas = tk.Tk()
canvas.geometry("600x500")
canvas.title("Weather App")
f = ("poppins", 15, "bold")
t = ("poppins", 35, "bold")

textField = tk.Entry(canvas, justify='center', width = 20, font = t)
textField.pack(pady = 20)
textField.focus()
textField.bind('<Return>', getweather)

label1 = tk.Label(canvas, font=t)
label1.pack()
label2 = tk.Label(canvas, font=f)
label2.pack()
canvas.mainloop()

# %% [markdown]
# ![WeatherData.PNG](attachment:WeatherData.PNG)

# %%
print(api_data)
# Out:
# {'coord': {'lon': 107.6186, 'lat': -6.9039}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 298.03, 'feels_like': 298.85, 'temp_min': 298.03, 'temp_max': 299.32, 'pressure': 929, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 2.24, 'deg': 309, 'gust': 2.68}, 'clouds': {'all': 96}, 'dt': 1642496846, 'sys': {'type': 2, 'id': 2043699, 'country': 'ID', 'sunrise': 1642459534, 'sunset': 1642504416}, 'timezone': 25200, 'id': 1650357, 'name': 'Bandung', 'cod': 200}
